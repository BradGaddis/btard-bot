# %%
from alpaca.trading.client import TradingClient
from config import *
import pandas as pd
from stocktrader import stock_trader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 3
#       1 # from alpaca.trading.client import TradingClient
#       2 from config import *
# ----> 3 import pandas as pd
#       4 from stocktrader import stock_trader
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# trading_client = TradingClient(ALPACA_PAPER_KEY, ALPACA_PAPER_SECRET_KEY)

# positions = trading_client.get_all_positions()

# pos_keys = [pos[0] for pos in positions[0]]

# pos_values = []
# i = 0
# for pos in positions:
#     pos_values.append([])
#     for tup in pos:
#         pos_values[i].append((tup[1]))
#     i += 1

# pos_df = pd.DataFrame(pos_values, columns=pos_keys)
# pos_df = pos_df.iloc[:,1:]
# pos_df

st = stock_trader()

st.get_position_df()
# Out:
#    symbol              exchange           asset_class         avg_entry_price  \
# 0     BKR  AssetExchange.NASDAQ  AssetClass.US_EQUITY                   25.25
# 1  BTCUSD    AssetExchange.FTXU     AssetClass.CRYPTO  19131.5885083568433949
# 2     IBM    AssetExchange.NYSE  AssetClass.US_EQUITY                  128.43
# 3      KR    AssetExchange.NYSE  AssetClass.US_EQUITY                   46.98
# 4     NEM    AssetExchange.NYSE  AssetClass.US_EQUITY                   53.01
# 5      VZ    AssetExchange.NYSE  AssetClass.US_EQUITY                   44.34
#
#              qty               side      market_value        cost_basis  \
# 0  151.035738463  PositionSide.LONG  3652.04415603534  3813.65239619075
# 1    0.000355876  PositionSide.LONG       6.855239388       6.808473192
# 2   29.565671783  PositionSide.LONG  3634.80368900202  3797.11922709069
# 3    41.71307194  PositionSide.LONG   1807.4274071602   1959.6801197412
# 4   71.942131601  PositionSide.LONG  3002.14515170973  3813.65239616901
# 5   85.645078362  PositionSide.LONG  3174.86305487934  3797.50277457108
#
#       unrealized_pl      unrealized_plpc unrealized_intraday_pl  \
# 0  -161.60824015541  -0.0423762376237624         37.75893461575
# 1       0.046766196   0.0068688228155103           -0.095374768
# 2  -162.31553808867  -0.0427470217238963         41.98325393186
# 3    -152.252712581  -0.0776926351638995          50.8899477668
# 4  -811.50724445928  -0.2127900396151669         30.21569527242
# 5  -622.63971969174  -0.1639603067207939         -9.42095861982
#
#   unrealized_intraday_plpc current_price lastday_price         change_today
# 0       0.0104471374843293         24.18         23.93   0.0104471374843293
# 1      -0.0137217756387282         19263         19531  -0.0137217756387282
# 2       0.0116853192890059        122.94        121.52   0.0116853192890059
# 3       0.0289717406791736         43.33         42.11   0.0289717406791736
# 4       0.0101670297748729         41.73         41.31   0.0101670297748729
# 5      -0.0029585798816568         37.07         37.18  -0.0029585798816568

# %%
# assests_in_portfolio = [asset.symbol for asset in positions]

# print(assests_in_portfolio)

print(st.get_position_tickers())
# Out:
# ['BKR', 'BTCUSD', 'IBM', 'KR', 'NEM', 'VZ']

# %%
def check_stock_financial(stock="msft"):
    # info = yf.Ticker(stock).info
    # # print(yf.Ticker(stock).info)
    # keys = [str(key) for key in info]
    # values = [info[key] for key in keys]
    # zipped = list(zip(keys,values))
    # # print(len(keys), len(values))
    # print(pd.DataFrame.from_dict(info))
    # print(zipped)
    # return pd.DataFrame(zipped, columns=keys)
    return yf.Ticker(stock).financials

check_stock_financial()

# %%
def check_stock_earnings(stock = "msft"):
    stock = yf.Ticker(stock)
    return stock.earnings

check_stock_earnings()

# %%
from pandas_datareader import data as pdr
yf.pdr_override()
ata = pdr.get_nasdaq_symbols()
ata = ata[ata.ETF == False]
ata = ata[ata["Listing Exchange"] == "N"]
ata = ata[ata["Test Issue"] == False]
ata

# %%
import csv
with open("nasdaq_tickers", "w") as f:
    write = csv.writer(f)
    write.writerow(ata.index.to_list())

# %%
metrics = []
with open("yahooinfometrics.csv", "r") as f:
    reader = csv.reader(f)
    metrics = list(reader)

for i in range(len(metrics[0])):
    metrics[0][i] = metrics[0][i].strip()

print(metrics)

# %%
# def get_stock_sustainability(stock = "msft"):
#     return yf.Ticker(stock).sustainability

# get_stock_sustainability()


def get_stock_info(stock = "msft"):
    info = yf.Ticker(stock).info
    list_out = [info[metric] for metric in metrics[0]]
    # for metric in metrics[0]:
    #     print(metric + ":", info[metric])
    # return info
    return list_out

get_stock_info()
